# %% [markdown]
# <strong>NBExtensions<strong>

# %%
#nbextensions
#Run the following in your command prompt
#!pip install jupyter_nbextensions_configurator
#https://medium.com/@rrfd/jupyter-notebook-shortcuts-tips-and-tricks-top-nbextensions-bring-order-to-your-notebooks-pt-1-b58f270963f9

# %%
import pandas as pd
xlsx = pd.ExcelFile('C:/Users/Michael/Dropbox/PhD/CU/0 - Courses/1- Fall 2018/Group Project - Solar Desal/Datasets/2 - Water Stress WRI/water_stress.xlsx')
df1 = pd.read_excel(xlsx, 'Baseline Water Stress')
df2 = pd.read_excel(xlsx, 'Drought Severity')

# %% [markdown]
# 1.) <strong>Baseline Water Stress <strong>

# %%
#Baseline Water Stress
df1.head()
# Out:
#                Country Water Stress
# 0  Antigua and Barbuda            5
# 1              Bahrain            5
# 2             Barbados            5
# 3              Comoros            5
# 4               Cyprus            5

# %%
df1["All sectors"].describe()
# Out:
# count     200
# unique    162
# top         -
# freq       20
# Name: All sectors, dtype: object

# %%
df1.set_index("Name",inplace=True)

# %%
#Shows countries with greatest to lowest water stress (5 = highest, 0 = lowest)
df1["All sectors"]
# Out:
# Name
# Antigua and Barbuda                           5
# Bahrain                                       5
# Barbados                                      5
# Comoros                                       5
# Cyprus                                        5
# Dominica                                      5
# Jamaica                                       5
# Malta                                         5
# Qatar                                         5
# Saint Lucia                                   5
# Saint Vincent and the Grenadines              5
# San Marino                                    5
# Singapore                                     5
# Trinidad and Tobago                           5
# United Arab Emirates                          5
# Western Sahara                                5
# Saudi Arabia                            4.99235
# Kuwait                                  4.96487
# Oman                                    4.91379
# ...

# %% [markdown]
# 2.) <strong>Drought Severity <strong>

# %% [markdown]
# Drought severity measures the average length of drought times the dryness of the droughts from 1901 to 2008. Drought is defined as a contiguous period when soil moisture remains below the 20th percentile. Length is measured in month and dryness is the average number of percentage points by which soil moisture drops below the 20th percentile.

# %%
df2.set_index("Name",inplace=True)
df2
# Out:
#                                   Rank All sectors
# Name
# Western Sahara                       1     4.42071
# Mauritania                           2     3.79019
# Niger                                3     3.72379
# Senegal                              4     3.64657
# Oman                                 5     3.41492
# Peru                                 6     3.38979
# Egypt                                7     3.35266
# Namibia                              8       3.299
# Qatar                                9     2.94453
# Sudan                               10     2.94119
# United Arab Emirates                11     2.91875
# Mali                                12     2.90066
# Armenia                             13     2.82779
# Jordan                              14     2.80048
# Libya                               15     2.76611
# Eritrea                             16     2.72977
# Botswana                            17     2.70227
# ...

# %%
#Shows countries with greatest drought severity
df2["All sectors"]
# Out:
# Name
# Western Sahara                       4.42071
# Mauritania                           3.79019
# Niger                                3.72379
# Senegal                              3.64657
# Oman                                 3.41492
# Peru                                 3.38979
# Egypt                                3.35266
# Namibia                                3.299
# Qatar                                2.94453
# Sudan                                2.94119
# United Arab Emirates                 2.91875
# Mali                                 2.90066
# Armenia                              2.82779
# Jordan                               2.80048
# Libya                                2.76611
# Eritrea                              2.72977
# Botswana                             2.70227
# Ecuador                              2.64303
# Turkmenistan                         2.61929
# Iran                                 2.57415
# Uzbekistan                           2.56691
# ...

# %%
df2["All sectors"].describe()
# Out:
# count     200
# unique    174
# top         -
# freq       20
# Name: All sectors, dtype: object

# %% [markdown]
# 3.) <strong>Wellhead Natural Gas Prices<strong>

# %%
#Natural Gas Prices
xls = pd.ExcelFile("C:/Users/Michael/Dropbox/PhD/CU/0 - Courses/1- Fall 2018/Group Project - Solar Desal/Datasets/3 - Natural Gas Prices/NGP.xls")
df3 = pd.read_excel(xls, 'Data 1')

# %%
df3
# Out:
#     Award date  Inflation Adjusted Wellhead Natural Gas Price
# 0         2017                                       0.000000
# 1         2016                                       0.000000
# 2         2015                                       0.000000
# 3         2014                                       0.000000
# 4         2013                                       0.000000
# 5         2012                                       2.839879
# 6         2011                                       4.304385
# 7         2010                                       5.036035
# 8         2009                                       4.193171
# 9         2008                                       9.073754
# 10        2007                                       7.388759
# 11        2006                                       7.769429
# 12        2005                                       9.199844
# 13        2004                                       7.084993
# ...

# %% [markdown]
# 4.) <strong>Population<strong> = from 1960 to 2017. Source = World Bank

# %%
xls = pd.ExcelFile('C:/Users/Michael/Dropbox/PhD/CU/0 - Courses/1- Fall 2018/Group Project - Solar Desal/Datasets/POPULATION/API_SP.POP.TOTL_DS2_EN_excel_v2.xls')
df4 = pd.read_excel(xls, 'Sheet1')

# %%
df4
# Out:
#                                           Country Name Country Code  \
# 0                                                Aruba          ABW
# 1                                          Afghanistan          AFG
# 2                                               Angola          AGO
# 3                                              Albania          ALB
# 4                                              Andorra          AND
# 5                                           Arab World          ARB
# 6                                 United Arab Emirates          ARE
# 7                                            Argentina          ARG
# 8                                              Armenia          ARM
# 9                                       American Samoa          ASM
# 10                                 Antigua and Barbuda          ATG
# 11                                           Australia          AUS
# 12                                             Austria          AUT
# ...

# %%
df4.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  2.600000e+02  2.600000e+02  2.600000e+02  2.600000e+02  2.600000e+02
# mean   1.178154e+08  1.193987e+08  1.215153e+08  1.241500e+08  1.268056e+08
# std    3.718574e+08  3.763198e+08  3.828766e+08  3.914229e+08  4.000141e+08
# min    4.279000e+03  4.453000e+03  4.566000e+03  4.656000e+03  4.748000e+03
# 25%    5.184015e+05  5.301480e+05  5.426568e+05  5.559520e+05  5.684168e+05
# 50%    3.669524e+06  3.734206e+06  3.839584e+06  3.955168e+06  4.074411e+06
# 75%    2.532754e+07  2.611541e+07  2.690508e+07  2.770050e+07  2.847884e+07
# max    3.032160e+09  3.073369e+09  3.126510e+09  3.191786e+09  3.257460e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.600000e+02  2.600000e+02  2.600000e+02  2.600000e+02  2.600000e+02
# mean   1.295275e+08  1.323946e+08  1.352566e+08  1.381695e+08  1.412246e+08
# ...

# %% [markdown]
# 5.) <strong> Population from UN (1950 to 2015)

# %%
xlsx = pd.ExcelFile('C:/Users/Michael/Dropbox/PhD/CU/0 - Courses/1- Fall 2018/Group Project - Solar Desal/Datasets/POPULATION/WPP2017_POP_F01_1_TOTAL_POPULATION_BOTH_SEXES.xlsx')
df5 = pd.read_excel(xlsx, 'ESTIMATES')

# %%
df5
# Out:
#                                                                                        Total population, both sexes combined, as of 1 July (thousands)  \
# Index Variant   Area                                               Notes Country code                                           1950.000
# 1     Estimates WORLD                                              NaN   900                                                 2536274.721
# 2     Estimates More developed regions                             a     901                                                  814865.069
# 3     Estimates Less developed regions                             b     902                                                 1721409.652
# 4     Estimates Least developed countries                          c     941                                                  195259.056
# 5     Estimates Less developed regions, excluding least develop... d     934                                                 1526150.596
# ...

# %%
df_base = pd.read_csv("C:/Users/Michael/Dropbox/PhD/CU/0 - Courses/1- Fall 2018/Group Project - Solar Desal/Datasets/Desal with other data.csv")

# %%
df_base
# Out:
#       Award date Capacity (m3/d)  Capacity (MGD)  \
# 0         2002.0          14,000            3.70
# 1         2002.0          14,000            3.70
# 2         2002.0          10,000            2.64
# 3         1992.0           5,760            1.52
# 4         1993.0           5,678            1.50
# 5         1988.0           5,000            1.32
# 6         2001.0           5,000            1.32
# 7         2002.0           5,000            1.32
# 8         2001.0           5,000            1.32
# 9         1978.0           4,800            1.27
# 10        1978.0           4,800            1.27
# 11        1971.0           4,542            1.20
# 12        1978.0           4,440            1.17
# 13        1978.0           4,440            1.17
# 14        1978.0           3,264            0.86
# 15        1993.0           3,000            0.79
# 16        1982.0           3,000            0.79
# 17        1981.0           2,880            0.76
# ...

# %%
df_base
# Out:
#       Award date Capacity (m3/d)  Capacity (MGD)  \
# 0         2002.0          14,000            3.70
# 1         2002.0          14,000            3.70
# 2         2002.0          10,000            2.64
# 3         1992.0           5,760            1.52
# 4         1993.0           5,678            1.50
# 5         1988.0           5,000            1.32
# 6         2001.0           5,000            1.32
# 7         2002.0           5,000            1.32
# 8         2001.0           5,000            1.32
# 9         1978.0           4,800            1.27
# 10        1978.0           4,800            1.27
# 11        1971.0           4,542            1.20
# 12        1978.0           4,440            1.17
# 13        1978.0           4,440            1.17
# 14        1978.0           3,264            0.86
# 15        1993.0           3,000            0.79
# 16        1982.0           3,000            0.79
# 17        1981.0           2,880            0.76
# ...

# %%
df_base_water_stress = pd.merge(df_base, df1, on= "Country")

# %%
df_base_water_stress
# Out:
#       Award date Capacity (m3/d)  Capacity (MGD)  \
# 0         2002.0          14,000            3.70
# 1         2002.0          14,000            3.70
# 2         2002.0          10,000            2.64
# 3         1992.0           5,760            1.52
# 4         1993.0           5,678            1.50
# 5         1988.0           5,000            1.32
# 6         2001.0           5,000            1.32
# 7         2002.0           5,000            1.32
# 8         2001.0           5,000            1.32
# 9         1978.0           4,800            1.27
# 10        1978.0           4,800            1.27
# 11        1971.0           4,542            1.20
# 12        1978.0           4,440            1.17
# 13        1978.0           4,440            1.17
# 14        1978.0           3,264            0.86
# 15        1993.0           3,000            0.79
# 16        1982.0           3,000            0.79
# 17        1981.0           2,880            0.76
# ...

# %%
df_base_water_stress.to_csv(r'C:\Users\Michael\Dropbox\PhD\CU\0 - Courses\1- Fall 2018\Group Project - Solar Desal\Datasets\Desal_Water Stress.csv')

# %%
df_base_water_stress["Water Stress"].describe()
# Out:
# count     6458.000000
# unique      92.000000
# top          4.992351
# freq      1233.000000
# Name: Water Stress, dtype: float64

# %%
df_base_water_stress["Water Stress"].isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 6428    False
# 6429    False
# 6430    False
# 6431    False
# 6432    False
# 6433    False
# 6434    False
# 6435    False
# 6436    False
# 6437    False
# 6438    False
# 6439    False
# 6440    False
# 6441    False
# 6442    False
# 6443    False
# 6444    False
# 6445    False
# 6446    False
# 6447    False
# 6448    False
# 6449    False
# 6450    False
# 6451    False
# 6452    False
# 6453    False
# 6454    False
# 6455    False
# 6456    False
# 6457    False
# ...

# %%
df_NGP = pd.merge(df_base_water_stress, df3, on= "Award date")

# %%
df_NGP
# Out:
#       Award date Capacity (m3/d)  Capacity (MGD)  \
# 0         2002.0          14,000            3.70
# 1         2002.0          14,000            3.70
# 2         2002.0          10,000            2.64
# 3         2002.0           5,000            1.32
# 4         2002.0           2,500            0.66
# 5         2002.0           2,500            0.66
# 6         2002.0           2,500            0.66
# 7         2002.0           2,500            0.66
# 8         2002.0           2,500            0.66
# 9         2002.0           2,500            0.66
# 10        2002.0           2,500            0.66
# 11        2002.0           2,400            0.63
# 12        2002.0           2,400            0.63
# 13        2002.0           1,300            0.34
# 14        2002.0           1,200            0.32
# 15        2002.0           1,200            0.32
# 16        2002.0             379            0.10
# 17        2002.0           1,090            0.29
# ...

# %%
df_NGP.to_csv(r'C:\Users\Michael\Dropbox\PhD\CU\0 - Courses\1- Fall 2018\Group Project - Solar Desal\Datasets\Desal_Water Stress_NGP.csv')

# %%
df_NGP
# Out:
#       Award date Capacity (m3/d)  Capacity (MGD)  \
# 0         2002.0          14,000            3.70
# 1         2002.0          14,000            3.70
# 2         2002.0          10,000            2.64
# 3         2002.0           5,000            1.32
# 4         2002.0           2,500            0.66
# 5         2002.0           2,500            0.66
# 6         2002.0           2,500            0.66
# 7         2002.0           2,500            0.66
# 8         2002.0           2,500            0.66
# 9         2002.0           2,500            0.66
# 10        2002.0           2,500            0.66
# 11        2002.0           2,400            0.63
# 12        2002.0           2,400            0.63
# 13        2002.0           1,300            0.34
# 14        2002.0           1,200            0.32
# 15        2002.0           1,200            0.32
# 16        2002.0             379            0.10
# 17        2002.0           1,090            0.29
# ...

# %%
df_NGP.isna()
# Out:
#       Award date  Capacity (m3/d)  Capacity (MGD)  \
# 0          False            False           False
# 1          False            False           False
# 2          False            False           False
# 3          False            False           False
# 4          False            False           False
# 5          False            False           False
# 6          False            False           False
# 7          False            False           False
# 8          False            False           False
# 9          False            False           False
# 10         False            False           False
# 11         False            False           False
# 12         False            False           False
# 13         False            False           False
# 14         False            False           False
# 15         False            False           False
# 16         False            False           False
# 17         False            False           False
# ...
